# %%
import soft_retrieval.content_scraping as cs

# %%
cfg = cs.CFrameGenerator("http://www.reddit.com")
# Out:
# DEBUG:root:Checking URL validity. Iteration: 0
# DEBUG:root:    URL Good.
# DEBUG:root:Sending request to url.
# INFO:urllib3.connectionpool:Starting new HTTP connection (1): www.reddit.com
# DEBUG:urllib3.connectionpool:Setting read timeout to None
# DEBUG:urllib3.connectionpool:"GET / HTTP/1.1" 301 0
# INFO:urllib3.connectionpool:Starting new HTTPS connection (1): www.reddit.com
# DEBUG:urllib3.connectionpool:Setting read timeout to None
# DEBUG:urllib3.connectionpool:"GET / HTTP/1.1" 200 25301
# DEBUG:root:    Got response!

# %%
cfg(class_name=".title, .may-blank",)
# Out:
#       tag                                               text
# 0       p                                      my subreddits
# 1       p  PsBattle: FedEx man extinguishes burning Ameri...
# 2       p  PsBattle: FedEx man extinguishes burning Ameri...
# 3       p  He just realized that he can never be a seal (...
# 4       p       He just realized that he can never be a seal
# 5       p       What do you have there marine? (i.imgur.com)
# 6       p                     What do you have there marine?
# 7       p  CBC crew hits pothole, gets flat tire while ga...
# 8       p  CBC crew hits pothole, gets flat tire while ga...
# 9       p  American civil war veterans shaking hands with...
# 10      p  American civil war veterans shaking hands with...
# 11      p  Oneonta Falls in the Columbia River Gorge (OR)...
# 12      p  Oneonta Falls in the Columbia River Gorge (OR)...
# 13      p  LPT: Always be the person who tells someone th...
# ...
